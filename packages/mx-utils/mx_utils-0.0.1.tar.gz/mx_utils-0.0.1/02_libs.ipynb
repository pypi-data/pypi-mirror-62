# %%
# default_exp libs

# %%
#hide
#test_flag_colab
from google.colab import drive
drive.mount('/content/drive')

# %%
#hide
# !pip install nbdev
# !pip install fastcore

# %%
#hide
# %cd /content/drive/My\ Drive/mx_utils

# %%
#hide
#test_flag_imports
from nbdev import * 
from nbdev.showdoc import *
from fastcore.test import *

# %% [markdown]
# # Libraries
#
# > Library imports, configurations and code examples.
